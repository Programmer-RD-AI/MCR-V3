# %%
# !unzip ./student\ \(1\).zip
# Out:
# Archive:  ./student (1).zip
# replace student-mat.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %% [markdown]
# ### Project Overview (Evaluation)
# - This is a test to find what dataset I am going to use. If this model has all of the matrix and parameter that I want I will use this dataset.
# - Target is over 65% Accuracy (What defines success : over 85%)
# - Data Taken from : https://archive.ics.uci.edu/ml/datasets/student+performance
#
# -------------------------------------------------------
#
# ### Problem Definition
#
# > Trying to predict a students marks and other parameter from data.
#
# -------------------------------------------------------
#
# ### Params of Dataset
# Attribute Information:
#
# #### Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
# 1 school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
#
# 2 sex - student's sex (binary: 'F' - female or 'M' - male)
#
# 3 age - student's age (numeric: from 15 to 22)
#
# 4 address - student's home address type (binary: 'U' - urban or 'R' - rural)
#
# 5 famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
#
# 6 Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
#
# 7 Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
#
# 8 Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
#
# 9 Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# 10 Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# 11 reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
#
# 12 guardian - student's guardian (nominal: 'mother', 'father' or 'other')
#
# 13 traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
#
# 14 studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#
# 15 failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#
# 16 schoolsup - extra educational support (binary: yes or no)
#
# 17 famsup - family educational support (binary: yes or no)
#
# 18 paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#
# 19 activities - extra-curricular activities (binary: yes or no)
#
# 20 nursery - attended nursery school (binary: yes or no)
#
# 21 higher - wants to take higher education (binary: yes or no)
#
# 22 internet - Internet access at home (binary: yes or no)
#
# 23 romantic - with a romantic relationship (binary: yes or no)
#
# 24 famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
# 25 freetime - free time after school (numeric: from 1 - very low to 5 - very high)
#
# 26 goout - going out with friends (numeric: from 1 - very low to 5 - very high)
#
# 27 Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 28 Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 29 health - current health status (numeric: from 1 - very bad to 5 - very good)
#
# 30 absences - number of school absences (numeric: from 0 to 93)
#
# #### these grades are related with the course subject, Math or Portuguese:
# 31 G1 - first period grade (numeric: from 0 to 20)
#
# 31 G2 - second period grade (numeric: from 0 to 20)
#
# 32 G3 - final grade (numeric: from 0 to 20, output target)
#
# the above infomation taken from https://archive.ics.uci.edu/ml/datasets/student+performance
#
# -------------------------------------------------------

# %% [markdown]
# ## Test
# becuase this is a test I am not going to do analytics in this test period but if I choose this dataset I will do some analytics

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import *
from sklearn.naive_bayes import *
from sklearn.linear_model import *
from sklearn.metrics import *
from sklearn.ensemble import *

# %%
data_1 = pd.read_csv('./student-mat.csv',delimiter=';')
data_2 = pd.read_csv('./student-por.csv',delimiter=';')
data = data_1
data = data.append(data_2)
data.dropna(inplace=True)

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
len(data)
# Out:
# 1044

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsu', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
data = data.drop(['school'],axis=1)

# %%
data.head()
# Out:
#   sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  reason  \
# 0   F   18       U     GT3       A     4     4  at_home   teacher  course
# 1   F   17       U     GT3       T     1     1  at_home     other  course
# 2   F   15       U     LE3       T     1     1  at_home     other   other
# 3   F   15       U     GT3       T     4     2   health  services    home
# 4   F   16       U     GT3       T     3     3    other     other    home
#
#    ... famrel  freetime  goout  Dalc Walc health absences  G1  G2  G3
# 0  ...      4         3      4     1    1      3        6   5   6   6
# 1  ...      5         3      3     1    1      3        4   5   5   6
# 2  ...      4         3      2     2    3      3       10   7   8  10
# 3  ...      3         2      2     1    1      5        2  15  14  15
# 4  ...      4         3      2     1    2      5        4   6  10  10
#
# [5 rows x 32 columns]

# %%
data = data.drop('Pstatus',axis=1)

# %%
data = data.drop('reason',axis=1)

# %%
data = data.drop('famrel',axis=1)

# %%
data = data.drop('Dalc',axis=1)

# %%
data = data.drop('Walc',axis=1)

# %%
data.head()
# Out:
#   sex  age address famsize  Medu  Fedu     Mjob      Fjob guardian  \
# 0   F   18       U     GT3     4     4  at_home   teacher   mother
# 1   F   17       U     GT3     1     1  at_home     other   father
# 2   F   15       U     LE3     1     1  at_home     other   mother
# 3   F   15       U     GT3     4     2   health  services   mother
# 4   F   16       U     GT3     3     3    other     other   father
#
#    traveltime  ...  higher  internet romantic freetime goout health absences  \
# 0           2  ...     yes        no       no        3     4      3        6
# 1           1  ...     yes       yes       no        3     3      3        4
# 2           1  ...     yes       yes       no        3     2      3       10
# 3           1  ...     yes       yes      yes        2     2      5        2
# 4           1  ...     yes        no       no        3     2      5        4
#
#    G1  G2  G3
# 0   5   6   6
# 1   5   5   6
# 2   7   8  10
# 3  15  14  15
# 4   6  10  10
#
# ...

# %%
g1_all = []
for g1 in data['G1']:
    g1_all.append(g1*5)

# %%
data['G1'] = g1_all

# %%
data.head()
# Out:
#   sex  age address famsize  Medu  Fedu     Mjob      Fjob guardian  \
# 0   F   18       U     GT3     4     4  at_home   teacher   mother
# 1   F   17       U     GT3     1     1  at_home     other   father
# 2   F   15       U     LE3     1     1  at_home     other   mother
# 3   F   15       U     GT3     4     2   health  services   mother
# 4   F   16       U     GT3     3     3    other     other   father
#
#    traveltime  ...  higher  internet romantic freetime goout health absences  \
# 0           2  ...     yes        no       no        3     4      3        6
# 1           1  ...     yes       yes       no        3     3      3        4
# 2           1  ...     yes       yes       no        3     2      3       10
# 3           1  ...     yes       yes      yes        2     2      5        2
# 4           1  ...     yes        no       no        3     2      5        4
#
#    G1  G2  G3
# 0  25   6   6
# 1  25   5   6
# 2  35   8  10
# 3  75  14  15
# 4  30  10  10
#
# ...

# %%
g2_all = []
for g2 in data['G2']:
    g2_all.append(g2*5)
data['G2'] = g2_all

# %%
data.head()
# Out:
#   sex  age address famsize  Medu  Fedu     Mjob      Fjob guardian  \
# 0   F   18       U     GT3     4     4  at_home   teacher   mother
# 1   F   17       U     GT3     1     1  at_home     other   father
# 2   F   15       U     LE3     1     1  at_home     other   mother
# 3   F   15       U     GT3     4     2   health  services   mother
# 4   F   16       U     GT3     3     3    other     other   father
#
#    traveltime  ...  higher  internet romantic freetime goout health absences  \
# 0           2  ...     yes        no       no        3     4      3        6
# 1           1  ...     yes       yes       no        3     3      3        4
# 2           1  ...     yes       yes       no        3     2      3       10
# 3           1  ...     yes       yes      yes        2     2      5        2
# 4           1  ...     yes        no       no        3     2      5        4
#
#    G1  G2  G3
# 0  25  30   6
# 1  25  25   6
# 2  35  40  10
# 3  75  70  15
# 4  30  50  10
#
# ...

# %%
data.columns
# Out:
# Index(['sex', 'age', 'address', 'famsize', 'Medu', 'Fedu', 'Mjob', 'Fjob',
#        'guardian', 'traveltime', 'studytime', 'failures', 'schoolsu', 'famsup',
#        'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic',
#        'freetime', 'goout', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['sex', 'age', 'address', 'famsize', 'Medu', 'Fedu', 'Mjob', 'Fjob',
#        'guardian', 'traveltime', 'studytime', 'failures', 'schoolsu', 'famsup',
#        'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic',
#        'freetime', 'goout', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
data.drop(['traveltime','romantic','nursery','higher'],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['sex', 'age', 'address', 'famsize', 'Medu', 'Fedu', 'Mjob', 'Fjob',
#        'guardian', 'studytime', 'failures', 'schoolsu', 'famsup', 'paid',
#        'activities', 'internet', 'freetime', 'goout', 'health', 'absences',
#        'G1', 'G2', 'G3'],
#       dtype='object')

# %%
data.head()
# Out:
#   sex  age address famsize  Medu  Fedu     Mjob      Fjob guardian  studytime  \
# 0   F   18       U     GT3     4     4  at_home   teacher   mother          2
# 1   F   17       U     GT3     1     1  at_home     other   father          2
# 2   F   15       U     LE3     1     1  at_home     other   mother          2
# 3   F   15       U     GT3     4     2   health  services   mother          3
# 4   F   16       U     GT3     3     3    other     other   father          2
#
#    ...  paid activities internet freetime goout health  absences  G1  G2  G3
# 0  ...    no         no       no        3     4      3         6  25  30   6
# 1  ...    no         no      yes        3     3      3         4  25  25   6
# 2  ...   yes         no      yes        3     2      3        10  35  40  10
# 3  ...   yes        yes      yes        2     2      5         2  75  70  15
# 4  ...   yes         no       no        3     2      5         4  30  50  10
#
# [5 rows x 23 columns]

# %%
g3_all = []
for g3 in data['G3']:
    g3_all.append(g3*5)
data['G3'] = g3_all

# %%
data.head()
# Out:
#   sex  age address famsize  Medu  Fedu     Mjob      Fjob guardian  studytime  \
# 0   F   18       U     GT3     4     4  at_home   teacher   mother          2
# 1   F   17       U     GT3     1     1  at_home     other   father          2
# 2   F   15       U     LE3     1     1  at_home     other   mother          2
# 3   F   15       U     GT3     4     2   health  services   mother          3
# 4   F   16       U     GT3     3     3    other     other   father          2
#
#    ...  paid activities internet freetime goout health  absences  G1  G2  G3
# 0  ...    no         no       no        3     4      3         6  25  30  30
# 1  ...    no         no      yes        3     3      3         4  25  25  30
# 2  ...   yes         no      yes        3     2      3        10  35  40  50
# 3  ...   yes        yes      yes        2     2      5         2  75  70  75
# 4  ...   yes         no       no        3     2      5         4  30  50  50
#
# [5 rows x 23 columns]

# %%
data['G1'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['G2'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data['G3'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
X = data.drop(['G1','G2','G3'],axis=1)
y = data.filter(['G1','G2','G3'],axis=1)

# %%
X.head()
# Out:
#   sex  age address famsize  Medu  Fedu     Mjob      Fjob guardian  studytime  \
# 0   F   18       U     GT3     4     4  at_home   teacher   mother          2
# 1   F   17       U     GT3     1     1  at_home     other   father          2
# 2   F   15       U     LE3     1     1  at_home     other   mother          2
# 3   F   15       U     GT3     4     2   health  services   mother          3
# 4   F   16       U     GT3     3     3    other     other   father          2
#
#    failures schoolsu famsup paid activities internet  freetime  goout  health  \
# 0         0      yes     no   no         no       no         3      4       3
# 1         0       no    yes   no         no      yes         3      3       3
# 2         3      yes     no  yes         no      yes         3      2       3
# 3         0       no    yes  yes        yes      yes         2      2       5
# 4         0       no    yes  yes         no       no         3      2       5
#
#    absences
# 0         6
# ...

# %%
X.drop('address',axis=1,inplace=True)

# %%
X.head()
# Out:
#   sex  age famsize  Medu  Fedu     Mjob      Fjob guardian  studytime  \
# 0   F   18     GT3     4     4  at_home   teacher   mother          2
# 1   F   17     GT3     1     1  at_home     other   father          2
# 2   F   15     LE3     1     1  at_home     other   mother          2
# 3   F   15     GT3     4     2   health  services   mother          3
# 4   F   16     GT3     3     3    other     other   father          2
#
#    failures schoolsu famsup paid activities internet  freetime  goout  health  \
# 0         0      yes     no   no         no       no         3      4       3
# 1         0       no    yes   no         no      yes         3      3       3
# 2         3      yes     no  yes         no      yes         3      2       3
# 3         0       no    yes  yes        yes      yes         2      2       5
# 4         0       no    yes  yes         no       no         3      2       5
#
#    absences
# 0         6
# 1         4
# 2        10
# 3         2
# ...

# %%
X = X.rename({'sex':'Gender','age':'Age','famsize':'Family_Size','Medu':'Mother_Education','Fedu':'Father_Education','guardian':'Guardian','studytime':'Studytime','failures':'Failures','schoolsu':'School_Support','famsup':'Family_Support','paid':'Extra_Classes','activities':'Extra_Activities','internet':'Internet_Access','health':'Health','absences':'Absent Times','goout':'Go_Out'},axis=1)

# %%
X.head()
# Out:
#   Gender  Age Family_Size  Mother_Education  Father_Education     Mjob  \
# 0      F   18         GT3                 4                 4  at_home
# 1      F   17         GT3                 1                 1  at_home
# 2      F   15         LE3                 1                 1  at_home
# 3      F   15         GT3                 4                 2   health
# 4      F   16         GT3                 3                 3    other
#
#        Fjob Guardian  Studytime  Failures School_Support Family_Support  \
# 0   teacher   mother          2         0            yes             no
# 1     other   father          2         0             no            yes
# 2     other   mother          2         3            yes             no
# 3  services   mother          3         0             no            yes
# 4     other   father          2         0             no            yes
#
#   Extra_Classes Extra_Activities Internet_Access  freetime  Go_Out  Health  \
# ...

# %%
import json
def object_to_int(data,column):
    info_dict = {}
    all_info = []
    index = -1
    for data_in_coloum in data[column]:
        if data_in_coloum not in info_dict:
            index = index + 1
            info_dict[data_in_coloum] = index
    for data_info_coloum_all_info in data[column]:
        all_info.append(info_dict[data_info_coloum_all_info])
    with open(f'{column}_info_object_to_int.json','w') as json_file:
        json.dump(info_dict,json_file)
    return all_info,info_dict,index

# %%
X.head()
# Out:
#   Gender  Age Family_Size  Mother_Education  Father_Education     Mjob  \
# 0      F   18         GT3                 4                 4  at_home
# 1      F   17         GT3                 1                 1  at_home
# 2      F   15         LE3                 1                 1  at_home
# 3      F   15         GT3                 4                 2   health
# 4      F   16         GT3                 3                 3    other
#
#        Fjob Guardian  Studytime  Failures School_Support Family_Support  \
# 0   teacher   mother          2         0            yes             no
# 1     other   father          2         0             no            yes
# 2     other   mother          2         3            yes             no
# 3  services   mother          3         0             no            yes
# 4     other   father          2         0             no            yes
#
#   Extra_Classes Extra_Activities Internet_Access  freetime  Go_Out  Health  \
# ...

# %%
X.dtypes
# Out:
# Gender              object
# Age                  int64
# Family_Size         object
# Mother_Education     int64
# Father_Education     int64
# Mjob                object
# Fjob                object
# Guardian            object
# Studytime            int64
# Failures             int64
# School_Support      object
# Family_Support      object
# Extra_Classes       object
# Extra_Activities    object
# Internet_Access     object
# freetime             int64
# Go_Out               int64
# Health               int64
# Absent Times         int64
# dtype: object

# %%
X['Gender'] = pd.Series(object_to_int(X,'Gender')[0]).T

# %%
X['Gender']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 644    1
# 645    1
# 646    0
# 647    0
# 648    0
# Name: Gender, Length: 1044, dtype: int64

# %%
X['Family_Size'] = pd.Series(object_to_int(X,'Family_Size')[0]).T
X['Mjob'] = pd.Series(object_to_int(X,'Mjob')[0]).T
X['Fjob'] = pd.Series(object_to_int(X,'Fjob')[0]).T
X['Guardian'] = pd.Series(object_to_int(X,'Guardian')[0]).T
X['School_Support'] = pd.Series(object_to_int(X,'School_Support')[0]).T
X['Family_Support'] = pd.Series(object_to_int(X,'Family_Support')[0]).T
X['Extra_Classes'] = pd.Series(object_to_int(X,'Extra_Classes')[0]).T
X['Extra_Activities'] = pd.Series(object_to_int(X,'Extra_Activities')[0]).T
X['Internet_Access'] = pd.Series(object_to_int(X,'Internet_Access')[0]).T

# %%
X.dtypes
# Out:
# Gender              int64
# Age                 int64
# Family_Size         int64
# Mother_Education    int64
# Father_Education    int64
# Mjob                int64
# Fjob                int64
# Guardian            int64
# Studytime           int64
# Failures            int64
# School_Support      int64
# Family_Support      int64
# Extra_Classes       int64
# Extra_Activities    int64
# Internet_Access     int64
# freetime            int64
# Go_Out              int64
# Health              int64
# Absent Times        int64
# dtype: object

# %%
import seaborn as sns

# %%
corr_matrix = data.corr()
fig,ax = plt.subplots(figsize=(15,10))
ax = sns.heatmap(corr_matrix,annot=True,linewidths=0.5,fmt='.2f',cmap='YlGnBu')

# %%
data.head()
# Out:
#   sex  age address famsize  Medu  Fedu     Mjob      Fjob guardian  studytime  \
# 0   F   18       U     GT3     4     4  at_home   teacher   mother          2
# 1   F   17       U     GT3     1     1  at_home     other   father          2
# 2   F   15       U     LE3     1     1  at_home     other   mother          2
# 3   F   15       U     GT3     4     2   health  services   mother          3
# 4   F   16       U     GT3     3     3    other     other   father          2
#
#    ...  paid activities internet freetime goout health  absences  G1  G2  G3
# 0  ...    no         no       no        3     4      3         6  25  30  30
# 1  ...    no         no      yes        3     3      3         4  25  25  30
# 2  ...   yes         no      yes        3     2      3        10  35  40  50
# 3  ...   yes        yes      yes        2     2      5         2  75  70  75
# 4  ...   yes         no       no        3     2      5         4  30  50  50
#
# [5 rows x 23 columns]

# %%
X = X.drop('freetime',axis=1,)

# %%
X.head()
# Out:
#    Gender  Age  Family_Size  Mother_Education  Father_Education  Mjob  Fjob  \
# 0       0   18            0                 4                 4     0     0
# 1       0   17            0                 1                 1     0     1
# 2       0   15            1                 1                 1     0     1
# 3       0   15            0                 4                 2     1     2
# 4       0   16            0                 3                 3     2     1
#
#    Guardian  Studytime  Failures  School_Support  Family_Support  \
# 0         0          2         0               0               0
# 1         1          2         0               1               1
# 2         0          2         3               0               0
# 3         0          3         0               1               1
# 4         1          2         0               1               1
#
#    Extra_Classes  Extra_Activities  Internet_Access  Go_Out  Health  \
# ...

# %%
data_new = pd.concat([X,y],axis=1)

# %%
corr_matrix = data_new.corr()
fig,ax = plt.subplots(figsize=(15,10))
ax = sns.heatmap(corr_matrix,annot=True,linewidths=0.5,fmt='.2f',cmap='YlGnBu')

# %%
corr_matrix = data_new.corr()
fig,ax = plt.subplots(figsize=(15,10))
ax = sns.heatmap(corr_matrix,annot=True,linewidths=0.5,fmt='.2f',cmap='YlGnBu')

# %%
data_new.corr().mean().mean()
# Out:
# 0.07785528118870634

# %%
data_new.columns
# Out:
# Index(['Gender', 'Age', 'Family_Size', 'Mother_Education', 'Father_Education',
#        'Mjob', 'Fjob', 'Guardian', 'Studytime', 'Failures', 'School_Support',
#        'Family_Support', 'Extra_Classes', 'Extra_Activities',
#        'Internet_Access', 'Go_Out', 'Health', 'Absent Times', 'G1', 'G2',
#        'G3'],
#       dtype='object')

# %%
for _ in range(2500):
    data_new = data_new.sample(frac=1)
for _ in range(2500):
    data_new = data_new.sample(frac=1)

# %%
X = data_new.drop(['G1','G2','G3'],axis=1)
y = data_new.drop(['Gender', 'Age', 'Family_Size', 'Mother_Education', 'Father_Education',
       'Mjob', 'Fjob', 'Guardian', 'School_Support','Failures','Studytime','Go_Out',
       'Family_Support', 'Extra_Classes', 'Extra_Activities', 'Health',
       'Absent Times'],axis=1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import *
from sklearn.metrics import *
from sklearn.ensemble import *
from sklearn.linear_model import *
from sklearn.tree import *
from sklearn.naive_bayes import *

# %%
def fit_and_calcuate_metrixs(models:dict,X_train,X_test,y_train,y_test):
    models_info = {}
    for name,model in models.items():
        print(name)
        model = model.fit(X_train,y_train)
        y_preds = model.predict(X_test)
        try:
            info = {
                'Accuracy':model.score(X_test,y_test),
                'MAE':mean_absolute_error(y_test,y_preds,average='macro'),
                'MSE':mean_squared_error(y_test,y_preds,average='macro'),
            }
            plot_confusion_matrix(model,X_test,y_test)
        except:
            info = {'Accuracy':model.score(X_test,y_test)}
        models_info[name] = info
        print('\n\n')
    return models_info
def calcuate_metrixs(models:dict,X_train,X_test,y_train,y_test):
    models_info = {}
    for name,model in models.items():
        print(name)
        y_preds = model.predict(X_test)
        info = {
            'Accuracy':model.score(X_test,y_test),
            'MAE':mean_absolute_error(y_test,y_preds,average='macro'),
            'MSE':mean_squared_error(y_test,y_preds,average='macro'),
        }
        plot_confusion_matrix(model,X_test,y_test)
        plot_roc_curve(model,X_test,y_test)
        models_info[name] = info
        print('\n\n')
    return models_info

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)
from sklearn.linear_model import SGDRegressor,SGDClassifier,Lasso,LassoLars,Ridge,RidgeClassifier
from sklearn.svm import SVC,SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import NearestNeighbors,KNeighborsRegressor,KNeighborsClassifier,RadiusNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
models = {
    'LinearRegression':LinearRegression(),
    'RandomForestRegressor':RandomForestRegressor(),
    'Lasso':Lasso(),
    'LassoLars':LassoLars(),
    'Ridge':Ridge(),
    'RandomForestRegressor':RandomForestRegressor(),
    'KNeighborsRegressor':KNeighborsRegressor(),
}
models_reg_results = fit_and_calcuate_metrixs(models,X_train,X_test,y_train,y_test)
models_reg_results = pd.DataFrame(models_reg_results.values(),models_reg_results.keys())
models_reg_results.plot.bar(figsize=(20,10))
# Out:
# LinearRegression
#
#
#
# RandomForestRegressor
#
#
#
# Lasso
#
#
#
# LassoLars
#
#
#
# Ridge
#
#
#
# KNeighborsRegressor
# <AxesSubplot:>

# %%
models_reg_results
# Out:
#                        Accuracy
# LinearRegression       0.380527
# RandomForestRegressor  0.231138
# Lasso                  0.126996
# LassoLars             -0.005773
# Ridge                  0.380723
# KNeighborsRegressor    0.045616

# %%
models_reg_results
cross_val_score(LinearRegression(),X,y,cv=10)
cross_val_score(Ridge(),X,y,cv=10)
grid = {
    'alpha':[2.5,5,7.5,10],
    'fit_intercept':[False,True], # If error remove False
    'normalize':[False,True],
    'copy_X':[False,True],
    'max_iter':[250,500,7500,1000],
    'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']
}
model = Ridge()
model = GridSearchCV(model,cv=2,param_grid=grid,verbose=25)
model.fit(X_train,y_train)
print(model.score(X_test,y_test))
# Out:
# Fitting 2 folds for each of 896 candidates, totalling 1792 fits
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=auto
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=auto, score=0.397, total=   0.0s
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=auto
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=auto, score=0.322, total=   0.0s
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=svd
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=svd, score=0.397, total=   0.0s
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=svd
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=svd, score=0.322, total=   0.0s
# ...

# %%
cross_val_score(Ridge(),X,y,cv=10)
# Out:
# array([0.37789842, 0.45844915, 0.43309835, 0.40324506, 0.34673219,
#        0.3850078 , 0.34707051, 0.40413219, 0.34295916, 0.34427074])

# %%
grid = {
    'fit_intercept':[False,True],
    'normalize':[False,True],
    'copy_X':[False,True],
}
LinearRegression_RS = GridSearchCV(LinearRegression(),cv=5,param_grid=grid)
LinearRegression_RS.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [False, True],
#                          'fit_intercept': [False, True],
#                          'normalize': [False, True]})

# %%
LinearRegression_RS.score(X_test,y_test)
# Out:
# 0.38052747823974037

# %%
grid = {
    'alpha':[2.5,5,7.5,10],
    'fit_intercept':[False,True], # If error remove False
    'normalize':[False,True],
    'copy_X':[False,True],
    'max_iter':[250,500,7500,1000],
    'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']
}
model = Ridge()
model = GridSearchCV(model,cv=2,param_grid=grid,verbose=25)
model.fit(X_train,y_train)
# Out:
# Fitting 2 folds for each of 896 candidates, totalling 1792 fits
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=auto
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=auto, score=0.397, total=   0.0s
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=auto
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=auto, score=0.322, total=   0.0s
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=svd
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=svd, score=0.397, total=   0.0s
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=svd
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=svd, score=0.322, total=   0.0s
# ...

# %%
model.score(X_test,y_test)*100
# Out:
# 38.09198885887887

# %%
import pickle
pickle.dump(model,open('1st_term_test_predictions_model.pkl','wb'))

# %%
data = data_new
X = data.drop(['G2','G3'],axis=1)

# %%
data.columns
# Out:
# Index(['Gender', 'Age', 'Family_Size', 'Mother_Education', 'Father_Education',
#        'Mjob', 'Fjob', 'Guardian', 'Studytime', 'Failures', 'School_Support',
#        'Family_Support', 'Extra_Classes', 'Extra_Activities',
#        'Internet_Access', 'Go_Out', 'Health', 'Absent Times', 'G1', 'G2',
#        'G3'],
#       dtype='object')

# %%
y = data.drop(['Gender', 'Age', 'Family_Size', 'Mother_Education', 'Father_Education',
       'Mjob', 'Fjob', 'Guardian', 'Studytime', 'Failures', 'School_Support',
       'Family_Support', 'Extra_Classes', 'Extra_Activities',
       'Internet_Access', 'Go_Out', 'Health', 'Absent Times', 'G1'],axis=1)

# %%
X = data.drop(['G2','G3'],axis=1)
y = data.drop(['Gender', 'Age', 'Family_Size', 'Mother_Education', 'Father_Education',
       'Mjob', 'Fjob', 'Guardian', 'Studytime', 'Failures', 'School_Support',
       'Family_Support', 'Extra_Classes', 'Extra_Activities',
       'Internet_Access', 'Go_Out', 'Health', 'Absent Times', 'G1'],axis=1)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)
from sklearn.linear_model import SGDRegressor,SGDClassifier,Lasso,LassoLars,Ridge,RidgeClassifier
from sklearn.svm import SVC,SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import NearestNeighbors,KNeighborsRegressor,KNeighborsClassifier,RadiusNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
models = {
    'LinearRegression':LinearRegression(),
    'RandomForestRegressor':RandomForestRegressor(),
    'Lasso':Lasso(),
    'LassoLars':LassoLars(),
    'Ridge':Ridge(),
    'RandomForestRegressor':RandomForestRegressor(),
    'KNeighborsRegressor':KNeighborsRegressor(),
}
models_reg_results = fit_and_calcuate_metrixs(models,X_train,X_test,y_train,y_test)
models_reg_results = pd.DataFrame(models_reg_results.values(),models_reg_results.keys())
models_reg_results.plot.bar(figsize=(20,10))
# Out:
# LinearRegression
#
#
#
# RandomForestRegressor
#
#
#
# Lasso
#
#
#
# LassoLars
#
#
#
# Ridge
#
#
#
# KNeighborsRegressor
# <AxesSubplot:>

# %%
models_reg_results
cross_val_score(LinearRegression(),X,y,cv=10)
cross_val_score(Ridge(),X,y,cv=10)
grid = {
    'alpha':[2.5,5,7.5,10],
    'fit_intercept':[False,True], # If error remove False
    'normalize':[False,True],
    'copy_X':[False,True],
    'max_iter':[250,500,7500,1000],
    'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']
}
model = Ridge()
model = GridSearchCV(model,cv=2,param_grid=grid,verbose=25)
model.fit(X_train,y_train)
print(model.score(X_test,y_test))
# Out:
# Fitting 2 folds for each of 896 candidates, totalling 1792 fits
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=auto
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=auto, score=0.664, total=   0.0s
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=auto
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=auto, score=0.696, total=   0.0s
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=svd
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=svd, score=0.664, total=   0.0s
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=svd
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, solver=svd, score=0.696, total=   0.0s
# ...

# %%
models_reg_results
# Out:
#                        Accuracy
# LinearRegression       0.703744
# RandomForestRegressor  0.735850
# Lasso                  0.719240
# LassoLars             -0.002843
# Ridge                  0.703889
# KNeighborsRegressor    0.693689

# %%
cross_val_score(LinearRegression(),X,y,cv=10)
# Out:
# array([0.74114197, 0.72956269, 0.64081039, 0.74988349, 0.70914443,
#        0.68773556, 0.69048621, 0.62625927, 0.68728735, 0.68110866])

# %%
cross_val_score(Ridge(),X,y,cv=10)
# Out:
# array([0.74120866, 0.72965925, 0.64081571, 0.74990389, 0.70920745,
#        0.68778783, 0.69047742, 0.62618676, 0.68734934, 0.6811956 ])

# %%
grid = {
    'alpha':[2.5,5,7.5,10],
    'fit_intercept':[False,True],
    'normalize':[False,True],
    'precompute':[False,True],
    'copy_X':[False,True],
    'max_iter':[250,500,750,1000],
    'warm_start':[False,True],
    'positive':[False,True],
    'positive':['cyclic','random']
}
model = Lasso()
model = GridSearchCV(model,cv=2,param_grid=grid,verbose=25)
model.fit(X_train,y_train)
print(model.score(X_test,y_test))
# Out:
# Fitting 2 folds for each of 1024 candidates, totalling 2048 fits
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, positive=cyclic, precompute=False, warm_start=False
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, positive=cyclic, precompute=False, warm_start=False, score=0.675, total=   0.0s
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, positive=cyclic, precompute=False, warm_start=False
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, positive=cyclic, precompute=False, warm_start=False, score=0.700, total=   0.0s
# [CV] alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, positive=cyclic, precompute=False, warm_start=True
# [CV]  alpha=2.5, copy_X=False, fit_intercept=False, max_iter=250, normalize=False, positive=cyclic, precompute=False, warm_start=True, score=0.675, total=   0.0s
# ...

# %%
print('Done')
# Out:
# Done

# %%
pickle.dump(model,open('2nd_term_test_predictions_model.pkl','wb'))

# %%
X = data.drop(['G3'],axis=1)
y = data.drop(['Gender', 'Age', 'Family_Size', 'Mother_Education', 'Father_Education',
       'Mjob', 'Fjob', 'Guardian', 'Studytime', 'Failures', 'School_Support',
       'Family_Support', 'Extra_Classes', 'Extra_Activities',
       'Internet_Access', 'Go_Out', 'Health', 'Absent Times', 'G1','G2'],axis=1)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)
from sklearn.linear_model import SGDRegressor,SGDClassifier,Lasso,LassoLars,Ridge,RidgeClassifier
from sklearn.svm import SVC,SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import NearestNeighbors,KNeighborsRegressor,KNeighborsClassifier,RadiusNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
models = {
    'LinearRegression':LinearRegression(),
    'RandomForestRegressor':RandomForestRegressor(),
    'Lasso':Lasso(),
    'LassoLars':LassoLars(),
    'Ridge':Ridge(),
    'RandomForestRegressor':RandomForestRegressor(),
    'KNeighborsRegressor':KNeighborsRegressor(),
}
models_reg_results = fit_and_calcuate_metrixs(models,X_train,X_test,y_train,y_test)
models_reg_results = pd.DataFrame(models_reg_results.values(),models_reg_results.keys())
models_reg_results.plot.bar(figsize=(20,10))
# Out:
# LinearRegression
#
#
#
# RandomForestRegressor
# <ipython-input-62-3f5e5c3b1d0b>:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model = model.fit(X_train,y_train)
# Lasso
#
#
#
# LassoLars
#
#
#
# Ridge
#
#
#
# KNeighborsRegressor
# <AxesSubplot:>

# %%
models_reg_results
# Out:
#                        Accuracy
# LinearRegression       0.848594
# RandomForestRegressor  0.850328
# Lasso                  0.851655
# LassoLars             -0.001183
# Ridge                  0.848611
# KNeighborsRegressor    0.830363

# %%
grid = {
    'n_neighbors':[5,25,50,75,100,125,250],
    'weights':['uniform','distance'],
    'algorithm':['auto','ball_tree','kd_tree','brute'],
    'leaf_size':[15,25,30,50,75,100],
    'p':[2,25,50,100],
}
model = KNeighborsRegressor()
model = GridSearchCV(model,cv=2,param_grid=grid,verbose=25)
model.fit(X_train,y_train)
print(model.score(X_test,y_test))
# Out:
# Fitting 2 folds for each of 1344 candidates, totalling 2688 fits
# [CV] algorithm=auto, leaf_size=15, n_neighbors=5, p=2, weights=uniform
# [CV]  algorithm=auto, leaf_size=15, n_neighbors=5, p=2, weights=uniform, score=0.810, total=   0.0s
# [CV] algorithm=auto, leaf_size=15, n_neighbors=5, p=2, weights=uniform
# [CV]  algorithm=auto, leaf_size=15, n_neighbors=5, p=2, weights=uniform, score=0.820, total=   0.0s
# [CV] algorithm=auto, leaf_size=15, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=auto, leaf_size=15, n_neighbors=5, p=2, weights=distance, score=0.810, total=   0.0s
# [CV] algorithm=auto, leaf_size=15, n_neighbors=5, p=2, weights=distance
# [CV]  algorithm=auto, leaf_size=15, n_neighbors=5, p=2, weights=distance, score=0.819, total=   0.0s
# [CV] algorithm=auto, leaf_size=15, n_neighbors=5, p=25, weights=uniform
# [CV]  algorithm=auto, leaf_size=15, n_neighbors=5, p=25, weights=uniform, score=0.808, total=   0.0s
# ...

# %%
print('Done')
# Out:
# Done

# %%
pickle.dump(model,open('3rd_term_test_predictions_model.pkl','wb'))

# %%
print('Done')
# Out:
# Done

# %%
print('Done')
# Out:
# Done

# %%
X.head()
# Out:
#      Gender  Age  Family_Size  Mother_Education  Father_Education  Mjob  Fjob  \
# 410       0   17            0                 2                 2     1     1
# 380       1   18            0                 4                 4     4     0
# 147       0   15            0                 1                 2     0     1
# 642       1   17            0                 4                 3     1     1
# 107       1   16            0                 3                 3     3     1
#
#      Guardian  Studytime  Failures  School_Support  Family_Support  \
# 410         0          2         0               1               1
# 380         1          2         0               1               0
# 147         0          2         0               1               1
# 642         1          2         0               1               1
# 107         1          3         0               1               1
#
#      Extra_Classes  Extra_Activities  Internet_Access  Go_Out  Health  \
# ...

# %%
print(':)')
# Out:
# :)
